# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
aug_2020 = pd.read_csv(r"C:\Users\laris\Documents\Tableau-homework\Resources\aug_2020.csv")
aug_df = pd.DataFrame(aug_2020)
aug_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717732
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717732
# 4              3185          City Hall               40.717732
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...

# %%
sep_2020 = pd.read_csv(r"C:\Users\laris\Documents\Tableau-homework\Resources\sep_2020.csv")
sep_df = pd.DataFrame(sep_2020)
sep_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           222  2020-09-01 00:15:58.6470  2020-09-01 00:19:40.8750
# 1           193  2020-09-01 00:49:00.7370  2020-09-01 00:52:14.3640
# 2           273  2020-09-01 00:51:44.5870  2020-09-01 00:56:17.7160
# 3          1419  2020-09-01 00:52:48.3160  2020-09-01 01:16:28.0490
# 4           254  2020-09-01 00:56:16.7170  2020-09-01 01:00:31.0870
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3640     Journal Square               40.733670
# 2              3191           Union St               40.718211
# 3              3203      Hamilton Park               40.727596
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3276  Marin Light Rail
# ...

# %%
oct_2020 = pd.read_csv(r"C:\Users\laris\Documents\Tableau-homework\Resources\oct_2020.csv")
oct_df = pd.DataFrame(oct_2020)
oct_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1           143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2           305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3          1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4           277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3273       Manila & 1st               40.721651
# 3              3199       Newport Pkwy               40.728745
# 4              3199       Newport Pkwy               40.728745
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3270      Jersey & 6th St
# ...

# %%
nov_2020 = pd.read_csv(r"C:\Users\laris\Documents\Tableau-homework\Resources\nov_2020.csv")
nov_df = pd.DataFrame(nov_2020)
nov_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           756  2020-11-01 00:11:32.6250  2020-11-01 00:24:09.5850
# 1           584  2020-11-01 00:14:20.4820  2020-11-01 00:24:04.7820
# 2           403  2020-11-01 00:22:55.8820  2020-11-01 00:29:39.0950
# 3           498  2020-11-01 00:41:37.4270  2020-11-01 00:49:55.7010
# 4           151  2020-11-01 00:53:21.2340  2020-11-01 00:55:52.8060
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3681           Grand St               40.715178
# 2              3203      Hamilton Park               40.727596
# 3              3268     Lafayette Park               40.713464
# 4              3185          City Hall               40.717732
#
#    start station longitude  end station id       end station name  \
# 0               -74.038914            3225  Baldwin at Montgomery
# ...

# %%
dec_2020 = pd.read_csv(r"C:\Users\laris\Documents\Tableau-homework\Resources\dec_2020.csv")
dec_df = pd.DataFrame(dec_2020)
dec_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
aug_dec =  pd.concat([aug_df, sep_df, oct_df, nov_df, dec_df], ignore_index=True)
aug_dec.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 160150          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 160151          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 160152          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 160153           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 160154          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# 160150              3199       Newport Pkwy               40.728745
# 160151              3184        Paulus Hook               40.714145
# 160152              3195            Sip Ave               40.730897
# 160153              3681           Grand St               40.715178
# 160154              3267       Morris Canal               40.712419
#
#         start station longitude  end station id end station name  \
# ...

# %%
aug_dec['gender']
# Out:
# 0         2
# 1         1
# 2         2
# 3         1
# 4         2
#          ..
# 160150    0
# 160151    0
# 160152    1
# 160153    0
# 160154    1
# Name: gender, Length: 160155, dtype: int64

# %%
aug_dec['Gender'] = aug_dec['gender'].replace([0,1,2],["Unknown","Male","Female"])
aug_dec = aug_dec.drop('gender', axis=1)
aug_dec.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717732
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717732
# 4              3185          City Hall               40.717732
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...

# %%
aug_dec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160155 entries, 0 to 160154
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             160155 non-null  int64
#  1   starttime                160155 non-null  object
#  2   stoptime                 160155 non-null  object
#  3   start station id         160155 non-null  int64
#  4   start station name       160155 non-null  object
#  5   start station latitude   160155 non-null  float64
#  6   start station longitude  160155 non-null  float64
#  7   end station id           160155 non-null  int64
#  8   end station name         160155 non-null  object
#  9   end station latitude     160155 non-null  float64
#  10  end station longitude    160155 non-null  float64
#  11  bikeid                   160155 non-null  int64
#  12  usertype                 160155 non-null  object
# ...

# %%
aug_dec.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# Gender                     False
# dtype: bool

# %%
aug_dec.to_csv(r"C:\Users\laris\Documents\Tableau-homework\Resources\aug_dec.csv")
